# %%
import pandas as pd
pd.set_option('display.max_columns', None)

path = "C:\Users\USER\Desktop\GitHub\Brasileirao-Analise\1. Data\Raw"

# Banco de dados org 
df_org = pd.read_csv(r"path+\barasileirao_dborg.gz", compression="gzip")

# Kaggle Adão

#df_KG_AD = pd.read_csv(path+"\\kaggle_AD\jogos.csv", sep=",")
df_KG_AD = pd.read_csv(r"path\to\kaggle_AD\jogos.csv", sep=",")

 

df_KG_AD.describe()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\j'
# <>:11: SyntaxWarning: invalid escape sequence '\j'
# C:\Users\USER\AppData\Local\Temp\ipykernel_5860\656274058.py:11: SyntaxWarning: invalid escape sequence '\j'
#   df_KG_AD = pd.read_csv(path+"\\kaggle_AD\jogos.csv", sep=",")
#                ID       rodata  mandante_Placar  visitante_Placar
# count  8405.00000  8405.000000      8405.000000       8405.000000
# mean   4203.00000    20.133254         1.541225          1.027008
# std    2426.45884    11.444643         1.230607          1.027170
# min       1.00000     1.000000         0.000000          0.000000
# 25%    2102.00000    10.000000         1.000000          0.000000
# 50%    4203.00000    20.000000         1.000000          1.000000
# 75%    6304.00000    30.000000         2.000000          2.000000
# max    8405.00000    46.000000         7.000000          7.000000
