# %%
import gzip
import pandas as pd
from io import StringIO
pd.set_option('display.max_columns', None)

# with gzip.open("br_db.gz", "rt", encoding="utf-8") as f:
#     conteudo = f.read()
#     df = conteudo

# df = pd.read_csv(StringIO(df), parse_dates=['data'])
# df = df.tail(6750)

# df.describe()
# # print(df.columns)
# # display(df)


# Lê o arquivo CSV compactado em Gzip
df = pd.read_csv(r"C:\Users\USER\Desktop\GitHub\Brasileirao-Analise\1. Data\Raw\br_db.gz", compression="gzip")

# Exibe as primeiras linhas
df.describe()
df.head(-3)
# Out:
#       ano_campeonato        data  rodada  \
# 0               2005  2005-10-08      31
# 1               2005  2005-04-23       1
# 2               2005  2005-08-21      21
# 3               2005  2005-08-28      23
# 4               2005  2005-06-26       9
# ...              ...         ...     ...
# 8445            2017  2017-08-03      18
# 8446            2017  2017-08-15      20
# 8447            2017  2017-10-17      28
# 8448            2017  2017-10-15      28
# 8449            2017  2017-10-22      30
#
#                                           estadio  \
# 0                  Estádio Durival Britto e Silva
# 1                  Estádio Durival Britto e Silva
# 2                  Estádio Durival Britto e Silva
# 3                  Estádio Durival Britto e Silva
# 4                  Estádio Olímpico Nilton Santos
# ...                                           ...
# 8445  Estádio Municipal Paulo Machado de Carvalho
# 8446  Estádio Municipal Paulo Machado de Carvalho
# ...
